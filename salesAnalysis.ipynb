# %%
import pandas as pd
sales=pd.read_csv('sales.csv')
sales
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
t10=sales.head(10)    #to get top 10 data's from csv file
t10
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
t10["Invoice ID"]     #to get invoice of all the purchase made
# Out:
# 0    460489604
# 1    471006167
# 2    411909258
# 3    487313402
# 4    197763430
# 5    263634050
# 6     99646662
# 7    188869875
# 8    325637547
# 9    562942936
# Name: Invoice ID, dtype: int64

# %%
sales['Category']    #to give all the categories of sale
# Out:
# 0      Groceries
# 1        Fashion
# 2       Clothing
# 3       Sporting
# 4          Books
#          ...
# 995    Groceries
# 996    Groceries
# 997     Clothing
# 998     Clothing
# 999     Clothing
# Name: Category, Length: 1000, dtype: object

# %%
sales['Category'].unique()  #it gives out unique categories of sales
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sales.iloc[100]   #it is used to get all the information of particular customer
# Out:
# Invoice ID    515862366
# Date          2/12/2018
# Time              10:57
# Gender           Female
# Location      Park lane
# City             Dallas
# Member               No
# Category       Sporting
# Price                94
# Quantity              6
# Total               564
# Payment            Card
# Rating                3
# Name: 100, dtype: object

# %%
sales[200:211]   #using slicicng to get data of for particular no of rows
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
# 210   236950025   3/9/2018  12:40  Female   Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 200  Groceries     82         1     82    Card       4
# ...

# %%
sales[sales['Gender']=='Female'].tail(10)     #getting last 10 data based on Gender condition
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 982   741817151  2/10/2018  14:43  Female   Brookfield  NewYork     No
# 983   169440268  2/17/2018  14:42  Female   Brookfield  NewYork     No
# 984   979059991  3/26/2018  13:48  Female   Brookfield  NewYork    Yes
# 986   321374195  3/17/2018  14:16  Female  Water tower  Chicago     No
# 987   245049016  1/20/2018  10:03  Female    Park lane   Dallas     No
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 982  Furniture     83         3    249    Gpay       1
# 983  Groceries      4         7     28    Gpay       5
# ...

# %%
sales[sales['Total']>=500].tail(10)        #getting records of transaction which are greater then 500
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 868   467636158  1/14/2018  14:33    Male    Park lane   Dallas    Yes
# 873   446058586  1/13/2018  12:02    Male  Water tower  Chicago     No
# 903   122276077  3/15/2018  17:29    Male   Brookfield  NewYork     No
# 913   949102124  2/10/2018  15:48  Female    Park lane   Dallas    Yes
# 924   309210649   2/9/2018  15:53  Female  Water tower  Chicago    Yes
# 955   696587127  3/13/2018  15:58    Male    Park lane   Dallas     No
# 961   736292714   2/8/2018  13:34  Female    Park lane   Dallas    Yes
# 979   719253789  3/15/2018  18:37  Female   Brookfield  NewYork     No
# 991   699906043  2/15/2018  12:58    Male   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 868    Fashion     91         6    546    Card       1
# 873  Groceries     73         7    511    Cash       3
# ...

# %%
sales['Payment'].unique()
# Out:
# array(['Cash', 'Card', 'Gpay'], dtype=object)

# %%
sales[sales['Payment']=='Gpay'].head(10)      #to display 10 transaction which is made using Gpay
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 5    263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14   547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 16   397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
# 22   761515143  1/15/2018  16:08  Female    Park lane   Dallas     No
# 23    56578535  3/23/2018  10:11    Male  Water tower  Chicago    Yes
# 25   833288071  1/25/2018  15:02    Male  Water tower  Chicago     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 3    Sporting     89         4    356    Gpay       1
# 5    Clothing     52         4    208    Gpay       3
# ...

# %%
sales.query('100<Total<200').head(10)      #to get all the data between 2 conditions
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 11   846531724  3/15/2018  12:12    Male    Park lane   Dallas     No
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
# 19   729486362   3/7/2018  12:50    Male  Water tower  Chicago     No
# 32   597934753  3/26/2018  16:46  Female   Brookfield  NewYork     No
# 33   419033295  3/24/2018  15:57    Male  Water tower  Chicago    Yes
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 2    Clothing     57         2    114    Cash       5
# ...

# %%
sales.query('City=="NewYork" & Payment=="Cash"').head(10)   #10 transaction which is made with cash and in NewYork city
# Out:
#      Invoice ID       Date   Time  Gender    Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male  Brookfield  NewYork    Yes
# 20    619639105  3/26/2018  19:48  Female  Brookfield  NewYork     No
# 31    567867755   2/3/2018  20:59  Female  Brookfield  NewYork     No
# 37    460044751  2/22/2018  16:20    Male  Brookfield  NewYork     No
# 70    554361739   1/2/2018  17:24    Male  Brookfield  NewYork    Yes
# 81    336967276  1/19/2018  17:54    Male  Brookfield  NewYork     No
# 94    435094946  1/12/2018  10:54    Male  Brookfield  NewYork     No
# 95    842361554  1/14/2018  16:17    Male  Brookfield  NewYork    Yes
# 119   198592951  3/16/2018  15:53  Female  Brookfield  NewYork    Yes
# 135   442355183  3/25/2018  14:48  Female  Brookfield  NewYork    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# 20   Groceries     44         6    264    Cash       1
# ...

# %%
sales.sum()['Quantity']    #to get sum of quantity of items sold
# Out:
# 4059

# %%
sales.sum()['Total']      #to get the total of all the transaction made
# Out:
# 207788

# %%
sales.max()['Total']    #Maximum amount spent by any customer
# Out:
# 693

# %%
sales[sales['Total']==sales.max()['Total']]      #Information about the customer who has spend most
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sales.min()['Total']  #Minimum amount spent by any customer
# Out:
# 1

# %%
sales[sales['Total']==sales.min()['Total']]      #Information about the customer who has spend least
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sales.groupby('City').sum()['Total']      #To get the sum of transaction of Each city
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sales.groupby('Date').sum()['Total']      #To get the sum of transaction of Each Date
# Out:
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
#representing totat transaction of a particular Location on a bar graph

# %%
#to get each location
location_list= sales.groupby('Location')
location = [x for x,y in location_list]
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
#to get sum of each transaction for each location
total=sales.groupby('Location').sum()['Total']
total
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(location,total)
plt.show()

# %%
#representing data of each location on pie chart


plt.pie(total,labels=location,autopct='%1.1f%%')
plt.show()

# %%
# mapping data based on gender and location
location_sales = sales.groupby(['Gender','Location']).count()['Invoice ID']
location_sales.unstack(level=0)
# Out:
# Gender       Female  Male
# Location
# Brookfield      179   161
# Park lane       179   153
# Water tower     143   185

# %%
unstacked_shopper=location_sales.unstack(level=0)

# %%
unstacked_shopper.plot(kind='bar')
plt.show()

# %%
spend=sales.groupby('Gender').sum()['Total']    #checking which gender spends more
spend
# Out:
# Gender
# Female    106452
# Male      101336
# Name: Total, dtype: int64

# %%
spend.plot(kind='bar')            #plotting for gender spending more
plt.show()

# %%
members = sales.groupby(['Member','Location']).count()['Invoice ID']
members.unstack(level=0)
# Out:
# Member        No  Yes
# Location
# Brookfield   173  167
# Park lane    167  165
# Water tower  159  169

# %%
#representation of data for members and non memebership customers



member_represent = members.unstack(level=0)
member_represent.plot(kind='bar')
plt.show()

# %%
member_spend=sales.groupby('Member').sum()['Total']    #checking wther member or non member are spending more
member_spend
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
member_spend.plot(kind='bar')
plt.show()

# %%
# finding the area with lowest and highest rating

rating = sales.groupby('Location').mean()['Rating']
rating.plot(kind='bar')
plt.show()

# %%
category_sales=sales.groupby('Category').count()['Quantity']
category_sales
# Out:
# Category
# Books        165
# Clothing     170
# Fashion      153
# Furniture    160
# Groceries    174
# Sporting     178
# Name: Quantity, dtype: int64

# %%
category_sales.plot(kind='bar')
plt.show()

# %%
Sales_gender=sales.groupby(['Gender','Category']).count()['Quantity']
Sales_gender
# Out:
# Gender  Category
# Female  Books        88
#         Clothing     81
#         Fashion      81
#         Furniture    78
#         Groceries    87
#         Sporting     86
# Male    Books        77
#         Clothing     89
#         Fashion      72
#         Furniture    82
#         Groceries    87
#         Sporting     92
# Name: Quantity, dtype: int64

# %%
newGender_sales=Sales_gender.unstack()
newGender_sales
# Out:
# Category  Books  Clothing  Fashion  Furniture  Groceries  Sporting
# Gender
# Female       88        81       81         78         87        86
# Male         77        89       72         82         87        92

# %%
newGender_sales.plot(kind='bar')
plt.show()

# %%
#creating new column with Day's

sales['Day']=pd.to_datetime(sales['Date']).dt.day
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# ...

# %%
#calculating total based on each day of each month
sales_day=sales.groupby('Day').sum()['Total']
sales_day
# Out:
# Day
# 1     6301
# 2     8247
# 3     8533
# 4     6593
# 5     9177
# 6     5976
# 7     6164
# 8     8313
# 9     9142
# 10    6444
# 11    4755
# 12    7714
# 13    5688
# 14    7978
# 15    9677
# 16    5912
# 17    5833
# 18    4625
# 19    7481
# 20    7333
# 21    4300
# 22    5788
# 23    6949
# 24    7819
# 25    8638
# 26    7165
# 27    8154
# 28    6467
# 29    4662
# 30    3530
# 31    2430
# Name: Total, dtype: int64

# %%
sales_day.plot()
plt.show()

# %%
sales['Hour']=pd.to_datetime(sales['Time']).dt.hour
sales.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  Hour
# 0  Groceries     30         1     30    Cash       2   25    16
# 1    Fashion     35         5    175    Card       3   19    16
# ...

# %%
#calculating total based on each day of each month
sales_hour=sales.groupby('Hour').sum()['Total']
sales_hour
# Out:
# Hour
# 10    20235
# 11    20274
# 12    17396
# 13    22146
# 14    15084
# 15    23717
# 16    14708
# 17    14443
# 18    20528
# 19    24221
# 20    15036
# Name: Total, dtype: int64

# %%
sales_hour.plot()
plt.show()

# %%
#finding which type of payment is used for each hour
payType_hour=sales.groupby(['Hour','Payment']).count()['Total']
payType_hour.unstack()
# Out:
# Payment  Card  Cash  Gpay
# Hour
# 10         29    35    37
# 11         25    36    29
# 12         27    27    35
# 13         35    37    31
# 14         22    32    29
# 15         37    38    27
# 16         23    31    23
# 17         28    21    25
# 18         25    29    39
# 19         34    32    47
# 20         26    26    23

# %%
uPay_Type=payType_hour.unstack()
uPay_Type.plot()
plt.show()
